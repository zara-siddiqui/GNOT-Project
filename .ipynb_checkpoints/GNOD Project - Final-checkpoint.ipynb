# %% [markdown]
# # Create your collection of songs & audio features

# %% [markdown]
# Instructions
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# retrieving secrets
#
# The clientid and clientsecret are stored in a file 'secrets.txt' in the following format:
# 2 lines,
# first line has 'clientid:ekjffee',
# second line has 'clientsecret:ksjbvdksbvksb',
# without the quotes and the commas, of course.
#
# The reason is that we want to keep this secret data out of our notebook. By creating a .gitignore file containing the name of the file secrets.txt on a line by its own, we prevent the secrets file from being pushed to github, and thereby being published for the world to see.

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'Client ID:ed1e16753c124a96a1357b5a21765ca8\nClient secret:c73a2c22c1bf4001b403e241de752cf6'

# %%
string.split('\n')
# Out:
# ['Client ID:ed1e16753c124a96a1357b5a21765ca8',
#  'Client secret:c73a2c22c1bf4001b403e241de752cf6']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
secrets_dict
# Out:
# {'Client ID': 'ed1e16753c124a96a1357b5a21765ca8',
#  'Client secret': 'c73a2c22c1bf4001b403e241de752cf6'}

# %% [markdown]
# authentication with secrets

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['Client ID'],
                                                           client_secret=secrets_dict['Client secret']))

# %%
# playlist = sp.user_playlist_tracks("spotify", "https://open.spotify.com/playlist/4RVf1hHtwvMEED3yuCNi8q?si=84ad4ca4b8694997")

# %%
playlist = sp.user_playlist_tracks("spotify", "1G8IpkZKobrIlXcVPoSIuf")

# %%
playlist["total"]
# Out:
# 10000

# %%
playlist['items']
# Out:
# [{'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#       'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#       'id': '74ASZWbe4lXaubB36ztrGX',
#       'name': 'Bob Dylan',
#       'type': 'artist',
#       'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6YabPKtZAjxwyWbuO9p4ZD'},
#     'href': 'https://api.spotify.com/v1/albums/6YabPKtZAjxwyWbuO9p4ZD',
#     'id': '6YabPKtZAjxwyWbuO9p4ZD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27341720ef0ae31e10d39e43ca2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0241720ef0ae31e10d39e43ca2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485141720ef0ae31e10d39e43ca2',
#       'width': 64}],
#     'name': 'Highway 61 Revisited',
#     'release_date': '1965-08-30',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6YabPKtZAjxwyWbuO9p4ZD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#      'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#      'id': '74ASZWbe4lXaubB36ztrGX',
#      'name': 'Bob Dylan',
#      'type': 'artist',
#      'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 369600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19922509'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3AhXZa8sUQht0UEdBJgpGc'},
#    'href': 'https://api.spotify.com/v1/tracks/3AhXZa8sUQht0UEdBJgpGc',
#    'id': '3AhXZa8sUQht0UEdBJgpGc',
#    'is_local': False,
#    'name': 'Like a Rolling Stone',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d48c45e3194cfe07470c85e50ca7dc7440661caa?cid=ed1e16753c124a96a1357b5a21765ca8',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3AhXZa8sUQht0UEdBJgpGc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#       'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#       'id': '6olE6TJLqED3rqDCT0FyPh',
#       'name': 'Nirvana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6okv1avxEgYSdc2JYy6ZEi'},
#     'href': 'https://api.spotify.com/v1/albums/6okv1avxEgYSdc2JYy6ZEi',
#     'id': '6okv1avxEgYSdc2JYy6ZEi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fdf71af87c2a4f3cbed53d65',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fdf71af87c2a4f3cbed53d65',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fdf71af87c2a4f3cbed53d65',
#       'width': 64}],
#     'name': 'Nevermind',
#     'release_date': '1991-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6okv1avxEgYSdc2JYy6ZEi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 301240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USGF19942501'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oTlkzk1OtrhH8wBAduVEi'},
#    'href': 'https://api.spotify.com/v1/tracks/3oTlkzk1OtrhH8wBAduVEi',
#    'id': '3oTlkzk1OtrhH8wBAduVEi',
#    'is_local': False,
#    'name': 'Smells Like Teen Spirit',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3oTlkzk1OtrhH8wBAduVEi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1PULmKbHeOqlkIwcDMNwD4'},
#     'href': 'https://api.spotify.com/v1/albums/1PULmKbHeOqlkIwcDMNwD4',
#     'id': '1PULmKbHeOqlkIwcDMNwD4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273525ce7c1045374f0f9e62965',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02525ce7c1045374f0f9e62965',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851525ce7c1045374f0f9e62965',
#       'width': 64}],
#     'name': "Sgt. Pepper's Lonely Hearts Club Band (Remastered)",
#     'release_date': '1967-06-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1PULmKbHeOqlkIwcDMNwD4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#      'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#      'id': '3WrFJ7ztbogyGnTHbHJFl2',
#      'name': 'The Beatles',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 337413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0601519'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ZFBeIyP41HhnALjxWy1pR'},
#    'href': 'https://api.spotify.com/v1/tracks/3ZFBeIyP41HhnALjxWy1pR',
#    'id': '3ZFBeIyP41HhnALjxWy1pR',
#    'is_local': False,
#    'name': 'A Day In The Life - Remastered',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:3ZFBeIyP41HhnALjxWy1pR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3oDbviiivRWhXwIE8hxkVV'},
#       'href': 'https://api.spotify.com/v1/artists/3oDbviiivRWhXwIE8hxkVV',
#       'id': '3oDbviiivRWhXwIE8hxkVV',
#       'name': 'The Beach Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:3oDbviiivRWhXwIE8hxkVV'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3yGRRfowVUIj29zEwgLYY7'},
#     'href': 'https://api.spotify.com/v1/albums/3yGRRfowVUIj29zEwgLYY7',
#     'id': '3yGRRfowVUIj29zEwgLYY7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739c4ab43fd03ed82bc2314eb0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029c4ab43fd03ed82bc2314eb0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519c4ab43fd03ed82bc2314eb0',
#       'width': 64}],
#     'name': 'Smiley Smile (Mono & Stereo)',
#     'release_date': '1967-09-18',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:3yGRRfowVUIj29zEwgLYY7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3oDbviiivRWhXwIE8hxkVV'},
#      'href': 'https://api.spotify.com/v1/artists/3oDbviiivRWhXwIE8hxkVV',
#      'id': '3oDbviiivRWhXwIE8hxkVV',
#      'name': 'The Beach Boys',
#      'type': 'artist',
#      'uri': 'spotify:artist:3oDbviiivRWhXwIE8hxkVV'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 219146,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA21202140'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Qt4Cc66g24QWwGP3YYV9y'},
#    'href': 'https://api.spotify.com/v1/tracks/5Qt4Cc66g24QWwGP3YYV9y',
#    'id': '5Qt4Cc66g24QWwGP3YYV9y',
#    'is_local': False,
#    'name': 'Good Vibrations (Mono)',
#    'popularity': 22,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5Qt4Cc66g24QWwGP3YYV9y'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/293zczrfYafIItmnmM3coR'},
#       'href': 'https://api.spotify.com/v1/artists/293zczrfYafIItmnmM3coR',
#       'id': '293zczrfYafIItmnmM3coR',
#       'name': 'Chuck Berry',
#       'type': 'artist',
#       'uri': 'spotify:artist:293zczrfYafIItmnmM3coR'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JNgzWgKmzKGTejspG2pjO'},
#     'href': 'https://api.spotify.com/v1/albums/0JNgzWgKmzKGTejspG2pjO',
#     'id': '0JNgzWgKmzKGTejspG2pjO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733800e4a141be64bc61ec1352',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023800e4a141be64bc61ec1352',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513800e4a141be64bc61ec1352',
#       'width': 64}],
#     'name': 'Chuck Berry Is On Top (Special Edition)',
#     'release_date': '1959',
#     'release_date_precision': 'year',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:0JNgzWgKmzKGTejspG2pjO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/293zczrfYafIItmnmM3coR'},
#      'href': 'https://api.spotify.com/v1/artists/293zczrfYafIItmnmM3coR',
#      'id': '293zczrfYafIItmnmM3coR',
#      'name': 'Chuck Berry',
#      'type': 'artist',
#      'uri': 'spotify:artist:293zczrfYafIItmnmM3coR'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 160892,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBJUT0917294'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7MH2ZclofPlTrZOkPzZKhK'},
#    'href': 'https://api.spotify.com/v1/tracks/7MH2ZclofPlTrZOkPzZKhK',
#    'id': '7MH2ZclofPlTrZOkPzZKhK',
#    'is_local': False,
#    'name': 'Johnny B Goode',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7MH2ZclofPlTrZOkPzZKhK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nwUJBm0HE4ZxD3f5cy5ok'},
#       'href': 'https://api.spotify.com/v1/artists/7nwUJBm0HE4ZxD3f5cy5ok',
#       'id': '7nwUJBm0HE4ZxD3f5cy5ok',
#       'name': 'Aretha Franklin',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nwUJBm0HE4ZxD3f5cy5ok'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5WndWfzGwCkHzAbQXVkg2V'},
#     'href': 'https://api.spotify.com/v1/albums/5WndWfzGwCkHzAbQXVkg2V',
#     'id': '5WndWfzGwCkHzAbQXVkg2V',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736aa9314b7ddfbd8f036ba3ac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026aa9314b7ddfbd8f036ba3ac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516aa9314b7ddfbd8f036ba3ac',
#       'width': 64}],
#     'name': 'I Never Loved a Man the Way I Love You',
#     'release_date': '1967-03-10',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:5WndWfzGwCkHzAbQXVkg2V'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nwUJBm0HE4ZxD3f5cy5ok'},
#      'href': 'https://api.spotify.com/v1/artists/7nwUJBm0HE4ZxD3f5cy5ok',
#      'id': '7nwUJBm0HE4ZxD3f5cy5ok',
#      'name': 'Aretha Franklin',
#      'type': 'artist',
#      'uri': 'spotify:artist:7nwUJBm0HE4ZxD3f5cy5ok'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'HT',
#     'JM',
#     'LS',
#     'LR',
#     'MW',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'LC',
#     'VC',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 147600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT20801240'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7s25THrKz86DM225dOYwnr'},
#    'href': 'https://api.spotify.com/v1/tracks/7s25THrKz86DM225dOYwnr',
#    'id': '7s25THrKz86DM225dOYwnr',
#    'is_local': False,
#    'name': 'Respect',
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7768dd513193e30ab1ad19deeff2dcc63d2c7555?cid=ed1e16753c124a96a1357b5a21765ca8',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7s25THrKz86DM225dOYwnr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CyeXFnOrfC1N6z4naIpgo'},
#       'href': 'https://api.spotify.com/v1/artists/7CyeXFnOrfC1N6z4naIpgo',
#       'id': '7CyeXFnOrfC1N6z4naIpgo',
#       'name': 'The Ronettes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CyeXFnOrfC1N6z4naIpgo'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3vLFWR3fLqfY82WGvaLuyV'},
#     'href': 'https://api.spotify.com/v1/albums/3vLFWR3fLqfY82WGvaLuyV',
#     'id': '3vLFWR3fLqfY82WGvaLuyV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734694c5b97d3a88efb5fc71b5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024694c5b97d3a88efb5fc71b5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514694c5b97d3a88efb5fc71b5',
#       'width': 64}],
#     'name': 'Be My Baby: The Very Best of The Ronettes',
#     'release_date': '2011-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:3vLFWR3fLqfY82WGvaLuyV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CyeXFnOrfC1N6z4naIpgo'},
#      'href': 'https://api.spotify.com/v1/artists/7CyeXFnOrfC1N6z4naIpgo',
#      'id': '7CyeXFnOrfC1N6z4naIpgo',
#      'name': 'The Ronettes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7CyeXFnOrfC1N6z4naIpgo'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 160906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQX91100088'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2G2YzndIA6jeWFPBXhUjh5'},
#    'href': 'https://api.spotify.com/v1/tracks/2G2YzndIA6jeWFPBXhUjh5',
#    'id': '2G2YzndIA6jeWFPBXhUjh5',
#    'is_local': False,
#    'name': 'Be My Baby',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1afcbd164ede375be899615268a947d6f96edaaa?cid=ed1e16753c124a96a1357b5a21765ca8',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2G2YzndIA6jeWFPBXhUjh5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3koiLjNrgRTNbOwViDipeA'},
#       'href': 'https://api.spotify.com/v1/artists/3koiLjNrgRTNbOwViDipeA',
#       'id': '3koiLjNrgRTNbOwViDipeA',
#       'name': 'Marvin Gaye',
#       'type': 'artist',
#       'uri': 'spotify:artist:3koiLjNrgRTNbOwViDipeA'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1GUfd3GzQ3QMOJwVphnwg0'},
#     'href': 'https://api.spotify.com/v1/albums/1GUfd3GzQ3QMOJwVphnwg0',
#     'id': '1GUfd3GzQ3QMOJwVphnwg0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273621dcbf02ada125b3d33951d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02621dcbf02ada125b3d33951d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851621dcbf02ada125b3d33951d',
#       'width': 64}],
#     'name': "What's Going On (Ecopac Remastered)",
#     'release_date': '1971-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1GUfd3GzQ3QMOJwVphnwg0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3koiLjNrgRTNbOwViDipeA'},
#      'href': 'https://api.spotify.com/v1/artists/3koiLjNrgRTNbOwViDipeA',
#      'id': '3koiLjNrgRTNbOwViDipeA',
#      'name': 'Marvin Gaye',
#      'type': 'artist',
#      'uri': 'spotify:artist:3koiLjNrgRTNbOwViDipeA'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 233000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO17100041'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0UAu4pJ44T9X2AmaUh1hHO'},
#    'href': 'https://api.spotify.com/v1/tracks/0UAu4pJ44T9X2AmaUh1hHO',
#    'id': '0UAu4pJ44T9X2AmaUh1hHO',
#    'is_local': False,
#    'name': "What's Going On",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0UAu4pJ44T9X2AmaUh1hHO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3koiLjNrgRTNbOwViDipeA'},
#       'href': 'https://api.spotify.com/v1/artists/3koiLjNrgRTNbOwViDipeA',
#       'id': '3koiLjNrgRTNbOwViDipeA',
#       'name': 'Marvin Gaye',
#       'type': 'artist',
#       'uri': 'spotify:artist:3koiLjNrgRTNbOwViDipeA'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1jcnZvZWvAGzNyQ7GNVy8X'},
#     'href': 'https://api.spotify.com/v1/albums/1jcnZvZWvAGzNyQ7GNVy8X',
#     'id': '1jcnZvZWvAGzNyQ7GNVy8X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360f5e8d519591d51e533e822',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260f5e8d519591d51e533e822',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160f5e8d519591d51e533e822',
#       'width': 64}],
#     'name': 'I Heard It Through The Grapevine / In The Groove (Stereo)',
#     'release_date': '1969-08-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1jcnZvZWvAGzNyQ7GNVy8X'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3koiLjNrgRTNbOwViDipeA'},
#      'href': 'https://api.spotify.com/v1/artists/3koiLjNrgRTNbOwViDipeA',
#      'id': '3koiLjNrgRTNbOwViDipeA',
#      'name': 'Marvin Gaye',
#      'type': 'artist',
#      'uri': 'spotify:artist:3koiLjNrgRTNbOwViDipeA'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 195266,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO16884718'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/27m1soUndRthrAA1ediOXn'},
#    'href': 'https://api.spotify.com/v1/tracks/27m1soUndRthrAA1ediOXn',
#    'id': '27m1soUndRthrAA1ediOXn',
#    'is_local': False,
#    'name': 'I Heard It Through The Grapevine',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:27m1soUndRthrAA1ediOXn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#       'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#       'id': '22bE4uQ6baNwSHPVcDxLCe',
#       'name': 'The Rolling Stones',
#       'type': 'artist',
#       'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/24V2ghp7XhGZzWKjthHq4v'},
#     'href': 'https://api.spotify.com/v1/albums/24V2ghp7XhGZzWKjthHq4v',
#     'id': '24V2ghp7XhGZzWKjthHq4v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1ba3816b76a35c8de273f00',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1ba3816b76a35c8de273f00',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1ba3816b76a35c8de273f00',
#       'width': 64}],
#     'name': 'Out Of Our Heads (Remastered)',
#     'release_date': '1965-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:24V2ghp7XhGZzWKjthHq4v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#      'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#      'id': '22bE4uQ6baNwSHPVcDxLCe',
#      'name': 'The Rolling Stones',
#      'type': 'artist',
#      'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 222813,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA176510160'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7fSGbZLhWlAiCC3HDPAULu'},
#    'href': 'https://api.spotify.com/v1/tracks/7fSGbZLhWlAiCC3HDPAULu',
#    'id': '7fSGbZLhWlAiCC3HDPAULu',
#    'is_local': False,
#    'name': "(I Can't Get No) Satisfaction - Mono Version / Remastered 2002",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:7fSGbZLhWlAiCC3HDPAULu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#       'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#       'id': '3fMbdgg4jU18AjLCKBhRSm',
#       'name': 'Michael Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1C2h7mLntPSeVYciMRTF4a'},
#     'href': 'https://api.spotify.com/v1/albums/1C2h7mLntPSeVYciMRTF4a',
#     'id': '1C2h7mLntPSeVYciMRTF4a',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734121faee8df82c526cbab2be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024121faee8df82c526cbab2be',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514121faee8df82c526cbab2be',
#       'width': 64}],
#     'name': 'Thriller 25 Super Deluxe Edition',
#     'release_date': '2008-02-08',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:1C2h7mLntPSeVYciMRTF4a'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#      'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#      'id': '3fMbdgg4jU18AjLCKBhRSm',
#      'name': 'Michael Jackson',
#      'type': 'artist',
#      'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 293826,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19902991'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5ChkMS8OtdzJeqyybCc9R5'},
#    'href': 'https://api.spotify.com/v1/tracks/5ChkMS8OtdzJeqyybCc9R5',
#    'id': '5ChkMS8OtdzJeqyybCc9R5',
#    'is_local': False,
#    'name': 'Billie Jean',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0f6b8a3524ec410020457da4cdd7717f9addce2f?cid=ed1e16753c124a96a1357b5a21765ca8',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5ChkMS8OtdzJeqyybCc9R5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
#       'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE',
#       'id': '43ZHCT0cAZBISjO8DG9PnE',
#       'name': 'Elvis Presley',
#       'type': 'artist',
#       'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0xbql9IlSeJSnFZjfryYuf'},
#     'href': 'https://api.spotify.com/v1/albums/0xbql9IlSeJSnFZjfryYuf',
#     'id': '0xbql9IlSeJSnFZjfryYuf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27341649a9940528d17e32ea5f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0241649a9940528d17e32ea5f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485141649a9940528d17e32ea5f0',
#       'width': 64}],
#     'name': 'Elvis 75',
#     'release_date': '2009-12-25',
#     'release_date_precision': 'day',
#     'total_tracks': 75,
#     'type': 'album',
#     'uri': 'spotify:album:0xbql9IlSeJSnFZjfryYuf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
# ...
#       'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy',
#       'id': '0oSGxfWSnnOXhD2fKuz2Gy',
#       'name': 'David Bowie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0vypdDHTQsoVmVu8OgXEly'},
#     'href': 'https://api.spotify.com/v1/albums/0vypdDHTQsoVmVu8OgXEly',
#     'id': '0vypdDHTQsoVmVu8OgXEly',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27305f234d08f6c0e14d1aab8a1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0205f234d08f6c0e14d1aab8a1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485105f234d08f6c0e14d1aab8a1',
#       'width': 64}],
#     'name': 'Hunky Dory',
#     'release_date': '1971-12-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0vypdDHTQsoVmVu8OgXEly'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oSGxfWSnnOXhD2fKuz2Gy'},
#      'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy',
#      'id': '0oSGxfWSnnOXhD2fKuz2Gy',
#      'name': 'David Bowie',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6itMJ1OJ3xL3LsxWb7xm28'},
#      'href': 'https://api.spotify.com/v1/artists/6itMJ1OJ3xL3LsxWb7xm28',
#      'id': '6itMJ1OJ3xL3LsxWb7xm28',
#      'name': 'Ken Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:6itMJ1OJ3xL3LsxWb7xm28'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 223413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJT19900030'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1C9NuEa1wOF15EOBuWaaxS'},
#    'href': 'https://api.spotify.com/v1/tracks/1C9NuEa1wOF15EOBuWaaxS',
#    'id': '1C9NuEa1wOF15EOBuWaaxS',
#    'is_local': False,
#    'name': 'Life On Mars? - 1999 Remastered Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1C9NuEa1wOF15EOBuWaaxS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fIvjotigTGWqjIz6EP1i4'},
#       'href': 'https://api.spotify.com/v1/artists/7fIvjotigTGWqjIz6EP1i4',
#       'id': '7fIvjotigTGWqjIz6EP1i4',
#       'name': 'Four Tops',
#       'type': 'artist',
#       'uri': 'spotify:artist:7fIvjotigTGWqjIz6EP1i4'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7pSmOdR07xSmTJBcwKKF0v'},
#     'href': 'https://api.spotify.com/v1/albums/7pSmOdR07xSmTJBcwKKF0v',
#     'id': '7pSmOdR07xSmTJBcwKKF0v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1fd264af3cc702830dc6d35',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1fd264af3cc702830dc6d35',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1fd264af3cc702830dc6d35',
#       'width': 64}],
#     'name': 'The Ultimate Collection: Four Tops',
#     'release_date': '1997-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 25,
#     'type': 'album',
#     'uri': 'spotify:album:7pSmOdR07xSmTJBcwKKF0v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fIvjotigTGWqjIz6EP1i4'},
#      'href': 'https://api.spotify.com/v1/artists/7fIvjotigTGWqjIz6EP1i4',
#      'id': '7fIvjotigTGWqjIz6EP1i4',
#      'name': 'Four Tops',
#      'type': 'artist',
#      'uri': 'spotify:artist:7fIvjotigTGWqjIz6EP1i4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 179666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO16700445'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2VwRmAIjgmwNPDh4eMK1EH'},
#    'href': 'https://api.spotify.com/v1/tracks/2VwRmAIjgmwNPDh4eMK1EH',
#    'id': '2VwRmAIjgmwNPDh4eMK1EH',
#    'is_local': False,
#    'name': "Reach Out I'll Be There - Single Version / Mono",
#    'popularity': 45,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2VwRmAIjgmwNPDh4eMK1EH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
#       'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE',
#       'id': '43ZHCT0cAZBISjO8DG9PnE',
#       'name': 'Elvis Presley',
#       'type': 'artist',
#       'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4GKfBd0gJ791c3Gp3umNho'},
#     'href': 'https://api.spotify.com/v1/albums/4GKfBd0gJ791c3Gp3umNho',
#     'id': '4GKfBd0gJ791c3Gp3umNho',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b913993b6b83288d427b39aa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b913993b6b83288d427b39aa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b913993b6b83288d427b39aa',
#       'width': 64}],
#     'name': 'The Complete Sun Sessions',
#     'release_date': '2005-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 38,
#     'type': 'album',
#     'uri': 'spotify:album:4GKfBd0gJ791c3Gp3umNho'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'},
#      'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE',
#      'id': '43ZHCT0cAZBISjO8DG9PnE',
#      'name': 'Elvis Presley',
#      'type': 'artist',
#      'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 120266,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UST7W0500424'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/38xhKLmi4SqnKMZy4ySBkD'},
#    'href': 'https://api.spotify.com/v1/tracks/38xhKLmi4SqnKMZy4ySBkD',
#    'id': '38xhKLmi4SqnKMZy4ySBkD',
#    'is_local': False,
#    'name': "That's All Right Mama",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:38xhKLmi4SqnKMZy4ySBkD'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GaxyUddsPok8BuhxN6OUW'},
#       'href': 'https://api.spotify.com/v1/artists/7GaxyUddsPok8BuhxN6OUW',
#       'id': '7GaxyUddsPok8BuhxN6OUW',
#       'name': 'James Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GaxyUddsPok8BuhxN6OUW'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1XUKCIGihksn1YVj3Z0RQK'},
#     'href': 'https://api.spotify.com/v1/albums/1XUKCIGihksn1YVj3Z0RQK',
#     'id': '1XUKCIGihksn1YVj3Z0RQK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27355f56961e555b3ecca2cb638',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0255f56961e555b3ecca2cb638',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485155f56961e555b3ecca2cb638',
#       'width': 64}],
#     'name': 'The Singles Vol. 7: 1970-1972',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 39,
#     'type': 'album',
#     'uri': 'spotify:album:1XUKCIGihksn1YVj3Z0RQK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GaxyUddsPok8BuhxN6OUW'},
#      'href': 'https://api.spotify.com/v1/artists/7GaxyUddsPok8BuhxN6OUW',
#      'id': '7GaxyUddsPok8BuhxN6OUW',
#      'name': 'James Brown',
#      'type': 'artist',
#      'uri': 'spotify:artist:7GaxyUddsPok8BuhxN6OUW'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 316253,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USF067025050'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1qvY84PQZYJ6ZLhQ9DEl2R'},
#    'href': 'https://api.spotify.com/v1/tracks/1qvY84PQZYJ6ZLhQ9DEl2R',
#    'id': '1qvY84PQZYJ6ZLhQ9DEl2R',
#    'is_local': False,
#    'name': 'Get Up (I Feel Like Being A) Sex Machine - Pt. 1 & 2',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1qvY84PQZYJ6ZLhQ9DEl2R'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-29T15:02:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#    'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#    'id': 'acclaimedmusic',
#    'type': 'user',
#    'uri': 'spotify:user:acclaimedmusic'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DaxqgrOhkeH0fpeiQq2f4'},
#       'href': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4',
#       'id': '2DaxqgrOhkeH0fpeiQq2f4',
#       'name': 'Oasis',
#       'type': 'artist',
#       'uri': 'spotify:artist:2DaxqgrOhkeH0fpeiQq2f4'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1FB977nQEiAr8jel6O2Zn3'},
#     'href': 'https://api.spotify.com/v1/albums/1FB977nQEiAr8jel6O2Zn3',
#     'id': '1FB977nQEiAr8jel6O2Zn3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27300a678b26ee5918f13202a68',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0200a678b26ee5918f13202a68',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485100a678b26ee5918f13202a68',
#       'width': 64}],
#     'name': "(What's The Story) Morning Glory",
#     'release_date': '1995-10-02',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1FB977nQEiAr8jel6O2Zn3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DaxqgrOhkeH0fpeiQq2f4'},
#      'href': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4',
#      'id': '2DaxqgrOhkeH0fpeiQq2f4',
#      'name': 'Oasis',
#      'type': 'artist',
#      'uri': 'spotify:artist:2DaxqgrOhkeH0fpeiQq2f4'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 258906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAW9500189'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5bj4hb0QYTs44PDiwbI5CS'},
#    'href': 'https://api.spotify.com/v1/tracks/5bj4hb0QYTs44PDiwbI5CS',
#    'id': '5bj4hb0QYTs44PDiwbI5CS',
#    'is_local': False,
#    'name': 'Wonderwall',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5bj4hb0QYTs44PDiwbI5CS'},
#   'video_thumbnail': {'url': None}}]

# %%
len(playlist["items"])
# Out:
# 100

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.playlist_tracks("1G8IpkZKobrIlXcVPoSIuf")
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        tracks.extend(results['items'])
        sleep(randint(1,3000)/1000)
    return tracks

# %%
playlist_id = '1G8IpkZKobrIlXcVPoSIuf'
all_tracks = get_playlist_tracks(playlist_id)
# all_tracks
# len(all_tracks)

# %%
tracks2 = json_normalize(all_tracks)
pd.set_option("display.max_columns", 0)
tracks2
# Out:
#                    added_at  is_local  ... video_thumbnail.url track
# 0      2020-11-29T15:02:07Z     False  ...                None   NaN
# 1      2020-11-29T15:02:07Z     False  ...                None   NaN
# 2      2020-11-29T15:02:07Z     False  ...                None   NaN
# 3      2020-11-29T15:02:07Z     False  ...                None   NaN
# 4      2020-11-29T15:02:07Z     False  ...                None   NaN
# ...                     ...       ...  ...                 ...   ...
# 19895  2020-11-29T15:02:07Z     False  ...                None   NaN
# 19896  2020-11-29T15:02:07Z     False  ...                None   NaN
# 19897  2020-11-29T15:02:07Z     False  ...                None   NaN
# 19898  2020-11-29T15:02:07Z     False  ...                None   NaN
# 19899  2020-11-29T15:02:07Z     False  ...                None   NaN
#
# [19900 rows x 41 columns]

# %%
tracks2.isnull().sum()
# Out:
# added_at                                  0
# is_local                                  0
# primary_color                         19900
# added_by.external_urls.spotify            0
# added_by.href                             0
# added_by.id                               0
# added_by.type                             0
# added_by.uri                              0
# track.album.album_type                  106
# track.album.artists                       4
# track.album.available_markets             4
# track.album.external_urls.spotify       106
# track.album.href                        106
# track.album.id                          106
# track.album.images                        4
# track.album.name                          4
# track.album.release_date                106
# track.album.release_date_precision      106
# track.album.total_tracks                106
# track.album.type                          4
# track.album.uri                         106
# track.artists                             4
# track.available_markets                   4
# track.disc_number                         4
# track.duration_ms                         4
# track.episode                           106
# track.explicit                            4
# track.external_ids.isrc                 108
# track.external_urls.spotify             106
# track.href                              106
# track.id                                106
# track.is_local                            4
# track.name                                4
# track.popularity                          4
# track.preview_url                     13325
# track.track                             106
# track.track_number                        4
# track.type                                4
# track.uri                                 4
# video_thumbnail.url                   19900
# track                                 19900
# dtype: int64

# %%
tracks2.dropna(subset=['track.album.artists'], inplace=True)

# %%
tracks2.isnull().sum()
# Out:
# added_at                                  0
# is_local                                  0
# primary_color                         19896
# added_by.external_urls.spotify            0
# added_by.href                             0
# added_by.id                               0
# added_by.type                             0
# added_by.uri                              0
# track.album.album_type                  102
# track.album.artists                       0
# track.album.available_markets             0
# track.album.external_urls.spotify       102
# track.album.href                        102
# track.album.id                          102
# track.album.images                        0
# track.album.name                          0
# track.album.release_date                102
# track.album.release_date_precision      102
# track.album.total_tracks                102
# track.album.type                          0
# track.album.uri                         102
# track.artists                             0
# track.available_markets                   0
# track.disc_number                         0
# track.duration_ms                         0
# track.episode                           102
# track.explicit                            0
# track.external_ids.isrc                 104
# track.external_urls.spotify             102
# track.href                              102
# track.id                                102
# track.is_local                            0
# track.name                                0
# track.popularity                          0
# track.preview_url                     13321
# track.track                             102
# track.track_number                        0
# track.type                                0
# track.uri                                 0
# video_thumbnail.url                   19896
# track                                 19896
# dtype: int64

# %%
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])

for i in range(len(tracks2)):
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity']
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
tracks2.iloc[5]['track.name']
# Out:
# 'Respect'

# %%
artists_df2
# Out:
#                                                  href  ... popularity
# 0   https://api.spotify.com/v1/artists/74ASZWbe4lX...  ...       72.0
# 0   https://api.spotify.com/v1/artists/6olE6TJLqED...  ...        0.0
# 0   https://api.spotify.com/v1/artists/3WrFJ7ztbog...  ...        0.0
# 0   https://api.spotify.com/v1/artists/3oDbviiivRW...  ...       22.0
# 0   https://api.spotify.com/v1/artists/293zczrfYaf...  ...        0.0
# ..                                                ...  ...        ...
# 0   https://api.spotify.com/v1/artists/2vwI9jlKSgJ...  ...       46.0
# 0   https://api.spotify.com/v1/artists/7xTKLpo7UCz...  ...        0.0
# 0   https://api.spotify.com/v1/artists/6nB0iY1cjSY...  ...        0.0
# 0   https://api.spotify.com/v1/artists/3LrsctPHK5w...  ...        0.0
# 0   https://api.spotify.com/v1/artists/1SQRv42e4Pj...  ...        0.0
#
# [21851 rows x 9 columns]

# %%
songs_data = artists_df2[['song_name', 'name', 'song_id', 'popularity', 'uri']]
songs_data
# Out:
#                          song_name  ...                                    uri
# 0             Like a Rolling Stone  ...  spotify:artist:74ASZWbe4lXaubB36ztrGX
# 0          Smells Like Teen Spirit  ...  spotify:artist:6olE6TJLqED3rqDCT0FyPh
# 0   A Day In The Life - Remastered  ...  spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# 0           Good Vibrations (Mono)  ...  spotify:artist:3oDbviiivRWhXwIE8hxkVV
# 0                   Johnny B Goode  ...  spotify:artist:293zczrfYafIItmnmM3coR
# ..                             ...  ...                                    ...
# 0                  Into The Valley  ...  spotify:artist:2vwI9jlKSgJbne3dlTzaLO
# 0               Tonight's Da Night  ...  spotify:artist:7xTKLpo7UCzXSnlH7fOIoM
# 0                         Figure 8  ...  spotify:artist:6nB0iY1cjSY1KyhYyuIIKH
# 0                    Like An Angel  ...  spotify:artist:3LrsctPHK5wMdvEqvFN8BW
# 0                     Come Dancing  ...  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
#
# [21851 rows x 5 columns]

# %% [markdown]
# # AUDIO FEATURES

# %%
songs_data.isnull().sum()
# Out:
# song_name       0
# name            0
# song_id       102
# popularity      0
# uri           102
# dtype: int64

# %%
songs_data.dropna(inplace=True)
# Out:
# C:\Users\zaras\AppData\Local\Temp\ipykernel_15112\965766301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   songs_data.dropna(inplace=True)

# %%
songs_data.shape
# Out:
# (21749, 5)

# %%
audio_features_list = []

chunks = [(i, i+100) for i in range(0, len(songs_data), 100)]

for chunk in chunks:
    id_list_100 = songs_data['song_id'][chunk[0]:chunk[1]].tolist()
    audio_features_list.extend(sp.audio_features(id_list_100))
    sleep(randint(1, 3000) / 1000)

len(audio_features_list)
# Out:
# 21749

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=songs_data,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                             song_name  ... time_signature
# 0                Like a Rolling Stone  ...              4
# 1             Smells Like Teen Spirit  ...              4
# 2      A Day In The Life - Remastered  ...              4
# 3              Good Vibrations (Mono)  ...              4
# 4                      Johnny B Goode  ...              4
# ...                               ...  ...            ...
# 21744                        Figure 8  ...              4
# 21745                   Like An Angel  ...              4
# 21746                   Like An Angel  ...              4
# 21747                    Come Dancing  ...              4
# 21748                    Come Dancing  ...              4
#
# [21749 rows x 23 columns]

# %%
audio_features_list = df_w_audio_ft

# %%
audio_features_list.to_csv('songs_database.csv', index=False)

# %% [markdown]
# # Clustering - KMeans

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
unique_columns = audio_features_list.columns.unique()
print(unique_columns)
# Out:
# Index(['song_name', 'name', 'song_id', 'popularity', 'uri_x', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id',
#        'uri_y', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
features_to_cluster = audio_features_list[['popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features_to_cluster)
pd.DataFrame(scaled_features,columns=features_to_cluster.columns).head()
# Out:
#    popularity  danceability    energy  ...     tempo  duration_ms  time_signature
# 0    1.901485     -0.536904  0.454947  ... -0.921993     0.885760        0.214018
# 1   -0.770582     -0.519205  1.065464  ... -0.149914     0.351825        0.214018
# 2   -0.770582     -1.233059 -0.680099  ...  1.510205     0.635323        0.214018
# 3    0.045883     -1.032472 -0.869274  ...  0.449187    -0.284870        0.214018
# 4   -0.770582     -0.324518  0.605426  ...  1.625093    -0.738127        0.214018
#
# [5 rows x 14 columns]

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, n_init="auto",
                    random_state=1234)
    kmeans.fit(scaled_features)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 6
#       3 inertia = []
#       5 for k in K:
# ----> 6     kmeans = KMeans(n_clusters=k, n_init="auto",
#       7                     random_state=1234)
#       8     kmeans.fit(scaled_features)
#       9     inertia.append(kmeans.inertia_)
#
# NameError: name 'KMeans' is not defined

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k, n_init="auto",
                    random_state=1234)
    kmeans.fit(scaled_features)
    silhouette.append(silhouette_score(scaled_features, kmeans.predict(scaled_features)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')

# %%
# optimal_k = 5, 8, 10, 14, 16

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(scaled_features)

# %%
clusters = kmeans.predict(scaled_features)

pd.Series(clusters).value_counts().sort_index()

# %%
clusters

# %%
cluster = pd.DataFrame({'clusters': clusters})

selected_columns = audio_features_list[['song_name', 'name', 'song_id', 'popularity']]

cluster_number = pd.concat([selected_columns, cluster], axis=1)

cluster_number

# %% [markdown]
# # Recommendation for song

# %%
song_input = input("Enter a song title or artist name: ")

song_input =  4

if user_input_cluster in cluster_number["clusters"].unique():
    cluster_songs = cluster_number[cluster_number["clusters"] == user_input_cluster]
    recommended_song = cluster_songs["song_name"].sample().iloc[0]
    artist_name = cluster_songs["name"].iloc[0] 
    
    print(recommended_song, 'by', artist_name)
